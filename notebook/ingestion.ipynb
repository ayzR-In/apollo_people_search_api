# %%
import psycopg2
import psycopg2.extras
import requests
import logging
import time
from ratelimit import limits, sleep_and_retry
from urllib.parse import quote
import os
from dotenv import load_dotenv
import json

# %%
load_dotenv()
API_KEY ='QqptYKkMpzTBN5q266dKpA'

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='./apollo_sync.log'
)

# %%
# Database Insertion Function
def insert_data(data_tuples):
    try:
        with psycopg2.connect(
            host = 'whitewolfden.myddns.me',
            database = 'abhinav-dev',
            user = 'kingslayer',
            password = '4Khc5D8+6T.3',
            port = '6204'
        ) as conn:
            
            with conn.cursor() as cur:
                insert_query = """
                INSERT INTO solar_contacts_without_salesforce_founder
                (id, first_name, last_name, linkedin, title, email, email_status, id_tracker,
                website, company_linkedin, work_history)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s::JSONB[])
                ON CONFLICT (id) DO UPDATE SET
                first_name = EXCLUDED.first_name,
                last_name = EXCLUDED.last_name,
                linkedin = EXCLUDED.linkedin,
                title = EXCLUDED.title,
                email = EXCLUDED.email,
                email_status = EXCLUDED.email_status,
                id_tracker = EXCLUDED.id_tracker,
                website = EXCLUDED.website,
                company_linkedin = EXCLUDED.company_linkedin,
                work_history = EXCLUDED.work_history;
                """

                formatted_data = [
                    (*t[:-1], [json.dumps(r) for r in t[-1]])
                    for t in data_tuples
                ]

                psycopg2.extras.execute_batch(cur, insert_query, formatted_data)
                conn.commit()

    except Exception as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()

# %%
# Update the status 
def status_updater():
    with psycopg2.connect(
            host = 'whitewolfden.myddns.me',
            database = 'abhinav-dev',
            user = 'kingslayer',
            password = '4Khc5D8+6T.3',
            port = '6204'
        ) as conn:
         with conn.cursor() as cur:
             update_query=(f"UPDATE solar_contacts_without_salesforce SET completed = TRUE WHERE website = ?",(website,))
    conn.close()

# %%
# Apollo API Calls

@sleep_and_retry
@limits(calls=150, period=60)
def people_search_api(company_url, current_page):

    base_url = "https://api.apollo.io/api/v1/mixed_people/search"

    default_params = {
        'q_organization_domains': company_url,
        'page': current_page,
        'per_page': 100
    }

    # Convert params to URL-encoded string
    query_string = '&'.join(f"{quote(str(k))}={quote(str(v))}" for k, v in default_params.items())
    url = f"{base_url}?{query_string}"

    headers = {
        "accept": "application/json",
        "Cache-Control": "no-cache",
        "Content-Type": "application/json",
        "x-api-key": API_KEY
    }

    try:
        response = requests.post(url, headers=headers)
        response.raise_for_status()
        data = response.json()
        logging.info(f'API request successful for {company_url} page {current_page}')
        return data
    except requests.exceptions.RequestException as e:
        print(e)
        return None

# %%
# Extract Data From Response From Contact
def extract_data_contact(response, contact_variable):
    data_tuples = []
    try:
        for i in range(len(response[contact_variable])):
            id = response[contact_variable][i]['id']
            first_name = response[contact_variable][i]['first_name']
            last_name = response[contact_variable][i]['last_name']
            linkedIn = response[contact_variable][i]['linkedin_url']
            title = response[contact_variable][i]['title']
            email = response[contact_variable][i]['email']
            email_status = response[contact_variable][i]['email_status']
            id_tracker = 'contact'
            website = response[contact_variable][i]['account']['website_url']
            company_linkedin = response[contact_variable][i]['account']['linkedin_url']
    
        records = []
        for j in range(len(response[contact_variable][i]['employment_history'])):
            record = {
                'company_name': response[contact_variable][i]['employment_history'][j]['organization_name'],
                'org_id': response[contact_variable][i]['employment_history'][j]['_id'],
                'title': response[contact_variable][i]['employment_history'][j]['title'],
                'start_date': response[contact_variable][i]['employment_history'][j]['start_date'],
                'end_date': response[contact_variable][i]['employment_history'][j]['end_date'],
            }
            records.append(record)
        thistuple = (id, first_name, last_name, linkedIn, title, email, email_status, id_tracker, website, company_linkedin, records)
        data_tuples.append(thistuple)
        if contact:
            status_updater(website)
    except Exception as error:
        print(error)
    
    return data_tuples

# %%
# Extract Data From Response From People
def extract_data_people(response, contact_variable):
    data_tuples = []
    try:
        for i in range(len(response[contact_variable])):
            id = response[contact_variable][i]['id']
            first_name = response[contact_variable][i]['first_name']
            last_name = response[contact_variable][i]['last_name']
            linkedIn = response[contact_variable][i]['linkedin_url']
            title = response[contact_variable][i]['title']
            email = response[contact_variable][i]['email']
            email_status = ''
            id_tracker = 'people'
            website = response[contact_variable][i]['account']['website_url']
            company_linkedin = response[contact_variable][i]['account']['linkedin_url']
    
        records = []
        for j in range(len(response[contact_variable][i]['employment_history'])):
            record = {
                'company_name': response[contact_variable][i]['employment_history'][j]['organization_name'],
                'org_id': response[contact_variable][i]['employment_history'][j]['_id'],
                'title': response[contact_variable][i]['employment_history'][j]['title'],
                'start_date': response[contact_variable][i]['employment_history'][j]['start_date'],
                'end_date': response[contact_variable][i]['employment_history'][j]['end_date'],
            }
            records.append(record)
        thistuple = (id, first_name, last_name, linkedIn, title, email, email_status, id_tracker, website, company_linkedin, records)
        data_tuples.append(thistuple)
        if people:
            status_updater(website)
    except Exception as error:
        print(error)
    
    return data_tuples

# %%
# Operating Apollo API
def calling_api(company_url, current_page):
    response = people_search_api(company_url, current_page)
    if response:
        current_page = int(response['pagination']['page'])
        total_pages = response['pagination']['total_pages']

    if response['contacts']:
        data_tuple = extract_data_contact(response, 'contacts')
        insert_data(data_tuple)
        

    if response['people']:
        data_tuple = extract_data_people(response, 'people')
        insert_data(data_tuple)

    if (total_pages > 1) and (current_page < total_pages): 
        calling_api(company_url, current_page + 1)

# %%
# Getting the List of URL from Database
def get_urls():
    conn = None
    try:
        with psycopg2.connect(
            host = 'whitewolfden.myddns.me',
            database = 'abhinav-dev',
            user = 'kingslayer',
            password = '4Khc5D8+6T.3',
            port = '6204'
        ) as conn:
            
            with conn.cursor() as cur:
                cur.execute("SELECT website FROM solar_companies_without_salesforce ORDER BY website ASC")
                table_content = cur.fetchall()
                table_content = [row[0] for row in table_content]
        
        return table_content
    except Exception as error:
        print(error)
        return[]
    finally:
        if conn is not None:
            conn.close()

# %%
# Main Function
def main():
    urls = get_urls()
    if urls is not None and len(urls) > 0:
        try:
            for url in urls:
                print(url)
                calling_api(url, 1)
                logging.info(f'Completed processing ...')
        except Exception as e:
            # logging.error(f'Main process error: {e}')
            print(e)

if __name__ == "__main__":
    main()
# Out:
# http://www.11millionacres.com
# http://www.127energy.com
# http://www.1876energy.com
# http://www.1solar.com
# http://www.1sourcesolar.com
# http://www.1starenergy.com
# http://www.1stcoastrecycling.net
# http://www.2etc.com
# http://www.350bayarea.org
# http://www.3bsforestry.com
# http://www.3xm.biz
# http://www.400brand.info
# http://www.4ctechnologies.com
# http://www.4ocean.com
# http://www.512solar.com
# http://www.603solar.com
# http://www.93energy.com
# http://www.9flagssolar.com
# http://www.a1energy.net
# http://www.a1organics.com
# http://www.aawems.com
# http://www.abound.com
# http://www.aboutsavingheat.com
# http://www.abpelectrical.com
# http://www.absolutesolar.com
# 'account'
# http://www.acba.africa
# http://www.accordpower.com
# http://www.acdcsolar.com
# http://www.acelfil.com
# http://www.acespace.org
# http://www.achievesolarflorida.com
# http://www.acrcd.org
# http://www.acrsolar.com
# http://www.actgroup.com.pk
# http://www.actionsolar.com
# http://www.activepowersolutions.com
# http://www.activesurfaces.xyz
# http://www.acuitypower.com
# http://www.adaptiverestoration.com
# http://www.adccom.com
# http://www.adicentsolar.com
# http://www.admetos.at
# http://www.adobesolar.com
# http://www.adonisrecycling.com
# http://www.adoptahighway.net
# http://www.adsolarusa.com
# http://www.adsorption.com
# http://www.aecrepro.com
# http://www.aec-usa.com
# http://www.aepros.com
# http://www.aerominetechnologies.com
# http://www.aes-midwest.com
# http://www.aesp.org
# http://www.affordableenergyconcepts.com
# http://www.africanenergy.com
# http://www.africanpeoplewildlife.org
# http://www.agilews.org
# http://www.agmet1.com
# http://www.ag-power.com
# http://www.agripowersolar.com
# http://www.agrisolar-eg.com
# http://www.agwafarm.com
# http://www.aikyum.com
# http://www.aileysolar.com
# http://www.airekoenergygroup.com
# http://www.airiver.io
# http://www.aissolar.com
# http://www.akatscrap.com
# http://www.akenergyauthority.org
# http://www.aksuda.com
# http://www.alabamarivers.org
# http://www.alabamawildlife.org
# http://www.albanysolarsolutions.com
# http://www.albionpower.com
# http://www.alcenrenewable.com
# 'website_url'
# http://www.alchemy-solar.com
# http://www.alercesolar.com
# http://www.aler-renovaveis.org
# http://www.alhodasolareg.com
# http://www.alisoelectric.net
# http://www.all4energy.org
# http://www.allcelltech.com
# http://www.alliedclearwater.com
# http://www.all-inremoval.com
# http://www.allpowerlabs.com
# http://www.allsolarenergy.com
# http://www.allstarsolarinc.com
# http://www.allsunsolutions.com
# http://www.allterrasolar.com
# http://www.alltialloys.com
# http://www.alpenglowsolar.com
# http://www.alpha-energy.com
# http://www.alphastruxure.com
# http://www.alternateenergyhawaii.com
# http://www.altersystems.com
# http://www.altestore.com
# http://www.altuspower.com
# http://www.aluminio.tech
# http://www.alwataniawater.com
# http://www.ambassadorenergy.com
# http://www.ambiasolar.com
# http://www.americanarraysolar.com
# http://www.americanbiosource.com
# http://www.americanenergyandsolar.com
# http://www.americanenergycare.com
# http://www.americanprairie.org
# http://www.americansolar.com
# http://www.americansolar.company
# http://www.americansolardirect.com
# http://www.americansolar.net
# http://www.americansunsolar.com
# http://www.americarb.com
# http://www.americusenergy.com
# http://www.ameriguardsvc.com
# http://www.ameriscraps.com
# http://www.amgsol.com
# http://www.amonix.com
# http://www.ampliform.com
# http://www.ampumpdrilling.com
# http://www.amsunsolar.com
# http://www.anbaric.com
# http://www.annaco.com
# http://www.ansmississippi.org
# http://www.antrum.com
# http://www.anuviaplantnutrients.com
# http://www.anvilcrawler.com
# http://www.apactpipelineawareness.com
# http://www.apcsolar.com
# http://www.apicalsolar.com
# http://www.apolloenergycompany.com
# http://www.apollosolarenergies.com
# http://www.appiawindservices.com
# http://www.appleblossomenergy.com
# http://www.apsmartglobal.com
# http://www.apsofny.com
# http://www.apteceg.com
# http://www.aptivesolar.com
# http://www.aptossolar.com
# http://www.apx.com
# 'website_url'
# http://www.aquacaresolar.com
# http://www.aquairr.com
# http://www.aquaria.world
# http://www.aquathermsolar.com
# http://www.aqua-waterfilter.com
# http://www.archaeaenergy.com
# 'website_url'
# http://www.arcticasolar.com
# http://www.arcturawind.com
# http://www.arenarenewables.com
# http://www.argentsolar.com
# http://www.argosandartemis.com
# http://www.ariaenergy.com
# http://www.ariasolarenergy.com
# http://www.arionglobal.com
# http://www.arisesolar.com.au
# 'website_url'
# http://www.arizonasolarwave.com
# http://www.arp-solar.com
# http://www.a-rsolar.com
# http://www.arsolarpowerinc.com
# http://www.artinenergy.com
# http://www.arzonsolar.com
# http://www.ascww.org
# http://www.asi.ag
# http://www.asoba.co
# http://www.aspenall.com
# http://www.aspsolartechnologiesllc.com
# http://www.asset-x.net
# http://www.assocenergy.com
# http://www.astralpower.com
# http://www.astrawatt.solar
# http://www.atecoo.com
# http://www.atlanticcompanies.com
# http://www.atlas-e.com
# http://www.atma-energy.com
# http://www.aurora-energy.com
# http://www.autoag.com
# http://www.auxiliusre.com
# http://www.avidwater.com
# http://www.avviosolar.com
# http://www.axiasolarusa.com
# http://www.axiawater.com
# http://www.axiomexergy.com
# http://www.axionpower.com
# http://www.axisrgintl.com
# http://www.azimuth-renewables.com
# http://www.azsunservices.com
# 'website_url'
# http://www.backflow.com
# http://www.backtothewild.org
# http://www.bairenergyllc.com
# http://www.barrierroofing.com
# http://www.batcon.org
# http://www.battgenie.life
# http://www.bay4.com
# http://www.bayeswater.com
# http://www.bayou.energy
# http://www.bayshorerecycling.com
# http://www.bccsolartx.com
# http://www.b-core.co
# http://www.bcrcd.org
# http://www.bearpeakpower.com
# http://www.beddingindustriesofamerica.com
# http://www.belmanco.com
# http://www.belwin.org
# http://www.bergmill.com
# http://www.berkerelywater.org
# http://www.berqrng.com
# http://www.besen-group.com
# http://www.bestdecisionsolar.com
# http://www.bestsolarnow.com
# http://www.betterearth.solar
# http://www.bettertogether.solar
# http://www.bettertomorrowsolar.com
# http://www.beyondsilicon.com
# http://www.biagreen.com
# http://www.biodaf.com
# http://www.biodiesel.com
# http://www.biodieselmisr.com
# http://www.bioeco.com.mx
# http://www.biofermenergy.com
# http://www.biofriendly.com
# http://www.biomassenergyresources.com
# http://www.biostarrenewables.com
# http://www.birchcreekdev.com
# http://www.bisonenergyusa.com
# http://www.blduke.com
# http://www.blossomsolar.com
# http://www.blueridgelandconservancy.org
# http://www.bluesesolar.com
# http://www.blueskysolarandroofing.com
# http://www.blueskysolarco.com
# http://www.bluewaterbaltimore.org
# http://www.blunrgy.com
# http://www.bobcatsolar.com
# http://www.bodhi.solar
# http://www.bostonenergyinc.com
# http://www.bowseat.org
# http://www.boxpower.io
# http://www.bpraptorcenter.org
# http://www.brightcarbonx.com
# http://www.brightcurrent.net
# http://www.brighthomeenergy.com
# http://www.brighthouse.solar
# http://www.brightleafpower.com
# http://www.brightnightpower.com
# http://www.brightsolarmarketing.com
# http://www.brightsun.solar
# http://www.brilliantlightpower.com
# http://www.britestreet.com
# http://www.brokersolar.com
# http://www.brookfieldrenewableus.com
# http://www.bsicr.com
# http://www.bsw-solar.de
# http://www.btlt.org
# http://www.btr.energy
# http://www.buildsolarenergy.com
# http://www.bullrockrenewables.com
# http://www.bulrushed.com
# http://www.burcellteam.com
# http://www.buroaklandtrust.org
# http://www.bur-oak-resources.ca
# http://www.buyrogz.com
# http://www.bwsresidential.net
# http://www.byldbetter.com
# http://www.c2pure.com
# http://www.cadizinc.com
# http://www.cae-estrie.com
# http://www.caes.org
# http://www.cairomatic.com
# http://www.cairo-solar.com
# http://www.calcerts.com
# http://www.calclean.com
# http://www.calebsolar.com
# http://www.calibrantenergy.com
# http://www.calicat.com
# http://www.californiasolarandelectric.com
# http://www.californiasolarguys.com
# http://www.calsolarinc.com
# http://www.calssa.org
# http://www.calwestrain.com
# http://www.calwind.com
# http://www.cannonsolar.com
# http://www.capefearsolarsystems.com
# http://www.capitalrcd.org
# http://www.capitalsolargroup.com
# http://www.carbongeocapture.com
# http://www.carefreesystems.com
# http://www.carolinasolarenergy.com
# http://www.carson-power.com
# http://www.cascadese.com
# http://www.caseysolar.com
# http://www.casingsinc.com
# http://www.casolargroup.com
# http://www.castawaysenergy.com
# http://www.castillope.com
# http://www.cawleyenvironmental.com
# http://www.cbsolar.miami
# http://www.cbssolar.com
# http://www.cdsolarenergy.com
# http://www.cectechinc.com
# http://www.cedarcreekenergy.com
# http://www.cega.com
# http://www.ceifiltration.com
# http://www.celadynetech.com
# http://www.cellagainusa.com
# http://www.celticenergy.com
# http://www.centennialwarehouse.com
# http://www.centralwaste.com
# http://www.cepsolar.com
# http://www.cescorp.com
# http://www.cesnrg.com
# http://www.cesolar.com
# http://www.ces-va.com
# http://www.cfvsolar.com
# http://www.cgbioenergy.com
# http://www.championsolar.net
# http://www.champlainorchards.com
# http://www.chargenetstations.com
# http://www.chicagosolarenergycompany.com
# http://www.chinahydroelectric.com
# http://www.ciellie.com
# http://www.cier.org
# 429 Client Error: Too Many Requests for url: https://api.apollo.io/api/v1/mixed_people/search?person_seniorities%5B%5D=owner&person_seriorities%5B%5D=founder&q_organization_domains=http%3A//www.cier.org&page=1&per_page=100
# 'NoneType' object is not subscriptable
